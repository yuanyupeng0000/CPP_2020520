# %%
#1.get the polygen coords from json
#2.get the polygen obj from image
#3.find another coords that has no iou with exited obj
#4.paste obj to image and json file

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

import os
import cv2
import PIL

from labelme import utils
import annotation_all_pipline as aapl
import random
import shapely
from shapely.geometry import Polygon
from collections import Counter
import datetime

#from cv2_bit_wise_op import *
SEED_JASON_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/\
data_annotated_test/'

def find_target_files(target_dir, endswith):
    all_files = os.listdir(target_dir)
    targets = []
    for f in all_files:
        if(f.endswith(endswith)):
            targets.append(f)
    return targets

def get_polygen_from_obj(jsobj):
    return jsobj['points']

def get_imgobj_from_polygen(polygen):
    return ''

def get_objs_from_json(json_file, datasets_name):
    data = json.load(open(json_file))
    objs = data[datasets_name]
    return objs

def get_imageData_from_json(json_file):
    data = json.load(open(json_file))
    img = data['imageData']
    img = utils.img_b64_to_arr(img)
    return img

def plt_show_img(img):
    plt.imshow(img)
    plt.show()
    
def polygons_to_mask(img_shape, polygons):
 
    mask = np.zeros(img_shape, dtype=np.uint8)
    mask = PIL.Image.fromarray(mask)
    xy = list(map(tuple, polygons))
    PIL.ImageDraw.Draw(mask).polygon(xy=xy, outline=1, fill=1)
    mask = np.array(mask, dtype=bool)
    return mask
 
def polygons_to_mask2(img_shape, polygons):
 
    mask = np.zeros(img_shape, dtype=np.uint8)
    polygons = np.asarray([polygons], np.int32) # 这里必须是int32，其他类型使用fillPoly会报错
    # cv2.fillPoly(mask, polygons, 1) # 非int32 会报错
    cv2.fillPoly(mask, polygons, (255,255,255))  # 非int32 会报错
    return mask

def get_random_point(y_max, x_max):
    array_x = np.arange(x_max)
    array_y = np.arange(y_max)
    random_x = random.sample(list(array_x), 1)[0]
    random_y = random.sample(list(array_y), 1)[0]
    return (random_x, random_y)

def caculate_move_vector(x_y_coords1, x_y_coords2):
    return (x_y_coords2[0] - x_y_coords1[0], x_y_coords2[1] - x_y_coords1[1])

def get_new_polygen(polygen, move_vector):
    new_polygen_array = np.array(polygen) + move_vector
    new_polygen_list = [list(i) for i in new_polygen_array]
    return  new_polygen_list

def get_bounding_rect(polygen):
    polygen_arry = np.array(polygen) # 必须是array数组的形式
    rect_1 = cv2.boundingRect(polygen_arry.astype(int)) #　(xmin,xmax,w,h)
    rect_2 = cv2.minAreaRect(polygen_arry.astype(int)) # 得到最小外接矩形的（中心(x,y), (宽,高), 旋转角度）
    return rect_1
def rect_2_bbox(rect):
    return [rect[0], int(rect[0]+rect[2]), 
            rect[1], int(rect[1]+rect[3])]

def get_polygens_from_json_objs(objs):
    return [o['points'] for o in objs]

def get_polygens_labels_from_json_objs(objs):
    return [o['label'] for o in objs]

def remove_seperated_obj_label(labels):
    label_dict = dict(Counter(labels))
    for k,v in label_dict.items():
        if(v > 1):
            labels = list(filter(lambda x:x!=k,labels))
    return labels

def check_new_polygen(polygens, new_polygen):
    polygen2 = Polygon(new_polygen)
    for p in polygens:
        polygen1 = Polygon(p)
        if(polygen1.intersects(polygen2)):
            return False
    return True   
def to_json_file(loaded_dict_data, file):
    with open(file, "w") as f:
        json.dump(loaded_dict_data, f)
        print("[ INFO ] write success !")

jsons = find_target_files(SEED_JASON_DIR, '.json')
jpgs = find_target_files(SEED_JASON_DIR, '.jpg')
jsons.sort()
jpgs.sort()
print(len(jpgs))
print(len(jsons))
# Out:
# 10
# 10

# %%
LOOP_TIMES = 1
for i in range(LOOP_TIMES):
    for j in jsons:
        data = json.load(open(SEED_JASON_DIR + j))
        #bs64img = data['imageData']
        #img = utils.img_b64_to_arr(bs64img)
        #img = img[:,:,(2,1,0)]
        print(SEED_JASON_DIR + j[:-5] + '.jpg')
        img = cv2.imread(SEED_JASON_DIR + j[:-5] + '.jpg')
        src = img.copy()
        print(img.shape)

        objs = get_objs_from_json(SEED_JASON_DIR + j, 'shapes')
        objs_extend = objs.copy()
        i = 0
        polygens = get_polygens_from_json_objs(objs)
        labels = get_polygens_labels_from_json_objs(objs)
        #labels = remove_seperated_obj_label(labels)
        for o in objs: #o is a dict
            o_extend = o.copy()
            label = o['label']
            os.system('mkdir -p ' + SEED_JASON_DIR + label)
            polygen = o['points']
            rect_src = get_bounding_rect(polygen)
            bbox_old = rect_2_bbox(rect_src)
            
            time_stamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
            mask = polygons_to_mask2(img.shape, polygen)
            mask_obj = mask[bbox_old[2]:bbox_old[3], bbox_old[0]:bbox_old[1],:]
            src_obj = img[bbox_old[2]:bbox_old[3], bbox_old[0]:bbox_old[1],:]
            cv2.imwrite(SEED_JASON_DIR + label + '/' + j[:-5] + '_' + str(i) + '_msk.jpg', mask_obj)
            cv2.imwrite(SEED_JASON_DIR + label + '/' + j[:-5] + '_' + str(i) + '_obj.jpg', src_obj)
            i += 1
# Out:
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_21000.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2505.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2513.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2517.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2520.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2523.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2526.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2534.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2543.jpg
# (1080, 1920, 3)
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2547.jpg
# (1080, 1920, 3)

# %%
LOOP_TIMES = 1
for i in range(LOOP_TIMES):
    for j in jsons:
        data = json.load(open(SEED_JASON_DIR + j))
        #bs64img = data['imageData']
        #img = utils.img_b64_to_arr(bs64img)
        #img = img[:,:,(2,1,0)]
        print(SEED_JASON_DIR + j[:-5] + '.jpg')
        img = cv2.imread(SEED_JASON_DIR + j[:-5] + '.jpg')
        src = img.copy()
        print(img.shape)

        objs = get_objs_from_json(SEED_JASON_DIR + j, 'shapes')
        objs_extend = objs.copy()
        i = 0
        polygens = get_polygens_from_json_objs(objs)
        labels = get_polygens_labels_from_json_objs(objs)
        #labels = remove_seperated_obj_label(labels)
        for o in objs: #o is a dict
            o_extend = o.copy()
            label = o['label']
            os.system('mkdir -p ' + SEED_JASON_DIR + label)
            if(label not in labels):
                print('seperate obj: ' + label + ', skip ...')
                continue
            polygen = o['points']
            rect_src = get_bounding_rect(polygen)
            bbox_old = rect_2_bbox(rect_src)
            LOOP = 50
            while(LOOP != 0):
                LOOP-=1
                bbox_new = aapl.generate_new_bbox_within_distance(img.shape,\
                (rect_src[3], rect_src[2]), bbox_old)
                move_vector = caculate_move_vector((bbox_old[0], bbox_old[2]),\
                (bbox_new[0], bbox_new[2]))
                new_polygen = get_new_polygen(polygen, move_vector)

                if(check_new_polygen(polygens, new_polygen)):
                    break
            if(LOOP == 0):
                continue
            o_extend['points'] = new_polygen
            time_stamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
            #o_extend['label'] = o['label'].split('-')[0] + '-' + time_stamp
            objs_extend.append(o_extend)
            polygens.append(new_polygen)
            mask = polygons_to_mask2(img.shape, new_polygen)
            '''
            mask_obj = mask[bbox_new[2]:bbox_new[3], bbox_new[0]:bbox_new[1],:]
            src_obj = img[bbox_old[2]:bbox_old[3], bbox_old[0]:bbox_old[1],:]

            cv2.imwrite(SEED_JASON_DIR + label + '/' + str(i) + '_msk.jpg', mask_obj)
            cv2.imwrite(SEED_JASON_DIR + label + '/' + str(i) + '_obj.jpg', src_obj)
            '''
            img[bbox_new[2]:bbox_new[3], bbox_new[0]:bbox_new[1],:] = \
            img[bbox_old[2]:bbox_old[3], bbox_old[0]:bbox_old[1],:]

            plgobj = cv2.bitwise_and(mask, img)
            
            mask_reverse = cv2.bitwise_not(mask)
            plgbkg = cv2.bitwise_and(src, mask_reverse)
            merged = cv2.add(plgbkg, plgobj)
            src = merged
            #cv2.imshow('merged', merged)
            i += 1
        time_stamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
        #cv2.imwrite(SEED_JASON_DIR + time_stamp + '.jpg', merged)
        data['shapes'] = objs_extend
        #merged = merged[:,:,(2,1,0)]
        #bs64img = utils.img_arr_to_b64(merged)
        #bs64img = bs64img.decode('utf-8') ### convert b' (byte to str)
        data['imageData'] = None
        data['imagePath'] = time_stamp + '.jpg'
        to_json_file(data, SEED_JASON_DIR + time_stamp + '.json')
    #break
# Out:
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_21000.jpg
# (1080, 1920, 3)
# seperate obj: car, skip ...
# seperate obj: car, skip ...
# seperate obj: car, skip ...
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2505.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2513.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2517.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2520.jpg
# (1080, 1920, 3)
# seperate obj: car, skip ...
# seperate obj: car, skip ...
# seperate obj: car, skip ...
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2523.jpg
# (1080, 1920, 3)
# seperate obj: car, skip ...
# seperate obj: car, skip ...
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2526.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2534.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2543.jpg
# (1080, 1920, 3)
# [ INFO ] write success !
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/JASON_DATASETS/data_annotated_test/MLYL-001马练营路龙城大街南20米路东由南向北高清球机_351010605140101_2020_04_13_07_01_07_2547.jpg
# (1080, 1920, 3)
# [ INFO ] write success !

# %%
data = json.load(open(SEED_JASON_DIR + jsons[0]))
bs64img = data['imageData']
img = utils.img_b64_to_arr(bs64img)
plt.imshow(img)
plt.show()

# %%
### json data format dict[key1:value1,key2:value2,keyn:valuen]
shapes = data['shapes'] ### data['shapes'] format list[{dict1}, {dict2}, {dictn}]
lbl, lbl_names = utils.labelme_shapes_to_label(img.shape, data['shapes']) 
print(lbl.shape)

# %%
img2 = img.copy()
img2[:,:,0] = lbl.copy()
img2[:,:,1] = lbl.copy()
img2[:,:,2] = lbl.copy()
img_new = cv2.multiply(img, img2)
img_bitwise = cv2.bitwise_and(img, img2)
cv2.imshow("test", img_bitwise)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_dst = cv2.bitwise_and(img, img, mask=lbl)

# %%
for i in range(749):
    for j in range(1428):
        if(lbl[i][j] != 0):
            print(lbl[i][j])

# %%
objs_extend
